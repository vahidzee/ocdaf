# %%
from score import Score
from cam import CAM
from tqdm import tqdm
import sys
sys.path.append("..")
import pandas as pd
from pathlib import Path
import yaml
# Out:
# No GPU automatically detected. Setting SETTINGS.GPU to 0, and SETTINGS.NJOBS to cpu_count.

# %%
def evaluate_model(data_configs, baseline_cls, baseline_args = None):
    data_configs = [str(x) for x in data_configs]
    baseline_args = {} if baseline_args is None else baseline_args
    results = []
    for config_file in tqdm(data_configs):
        data_config = yaml.load(open(config_file, "r"), Loader=yaml.FullLoader)["init_args"]
        baseline = baseline_cls(
            dataset=data_config["dataset"],
            dataset_args=data_config["dataset_args"],
            **baseline_args
        )
        results.append({"name": config_file.split("/")[-1].split(".")[0], "baseline": baseline.name, **baseline.evaluate()})
        
    return pd.DataFrame(results)

# %%
evaluate_model(list(Path("../experiments/data/test/").glob("*.yaml")), CAM)
# Out:
# 100%|██████████| 21/21 [00:27<00:00,  1.31s/it]
#                                               name baseline  backward_count  \
# 0          linear_non_gaussian_3_1000_full_uniform      CAM               3
# 1   linear_non_gaussian_3_1000_v_structure_laplace      CAM               1
# 2          linear_non_gaussian_4_1000_full_uniform      CAM               5
# 3   linear_non_gaussian_3_1000_erdos_renyi_uniform      CAM               1
# 4         linear_non_gaussian_2_1000_chain_laplace      CAM               1
# 5   linear_non_gaussian_4_1000_v_structure_laplace      CAM               2
# 6         linear_non_gaussian_3_1000_chain_uniform      CAM               1
# 7   linear_non_gaussian_4_1000_erdos_renyi_uniform      CAM               2
# 8          linear_non_gaussian_4_1000_fork_uniform      CAM               3
# 9          linear_non_gaussian_3_1000_fork_uniform      CAM               1
# 10        linear_non_gaussian_4_1000_chain_uniform      CAM               3
# 11  linear_non_gaussian_3_1000_erdos_renyi_laplace      CAM               2
# 12         linear_non_gaussian_4_1000_full_laplace      CAM               4
# 13        linear_non_gaussian_2_1000_chain_uniform      CAM               1
# 14         linear_non_gaussian_3_1000_full_laplace      CAM               3
# 15  linear_non_gaussian_4_1000_erdos_renyi_laplace      CAM               1
# 16        linear_non_gaussian_3_1000_chain_laplace      CAM               2
# 17  linear_non_gaussian_4_1000_v_structure_uniform      CAM               2
# 18         linear_non_gaussian_3_1000_fork_laplace      CAM               2
# 19         linear_non_gaussian_4_1000_fork_laplace      CAM               2
# 20        linear_non_gaussian_4_1000_chain_laplace      CAM               3
#
#     backward_relative_penalty true_ordering estimated_ordering
# 0                    1.000000     [1, 2, 0]          [0, 2, 1]
# 1                    0.500000     [0, 2, 1]          [0, 1, 2]
# 2                    0.833333  [3, 2, 1, 0]       [1, 0, 2, 3]
# 3                    0.333333     [1, 0, 2]          [0, 1, 2]
# 4                    1.000000        [1, 0]             [0, 1]
# 5                    0.666667  [0, 3, 1, 2]       [1, 2, 0, 3]
# 6                    0.500000     [1, 2, 0]          [0, 1, 2]
# 7                    0.666667  [3, 0, 1, 2]       [1, 3, 2, 0]
# 8                    1.000000  [3, 2, 1, 0]       [2, 1, 0, 3]
# 9                    0.500000     [2, 0, 1]          [1, 2, 0]
# 10                   1.000000  [1, 0, 3, 2]       [2, 3, 0, 1]
# 11                   1.000000     [0, 1, 2]          [2, 1, 0]
# 12                   0.666667  [1, 3, 0, 2]       [0, 2, 1, 3]
# 13                   1.000000        [1, 0]             [0, 1]
# 14                   1.000000     [1, 2, 0]          [0, 2, 1]
# 15                   1.000000  [3, 0, 2, 1]       [1, 3, 2, 0]
# 16                   1.000000     [1, 0, 2]          [2, 0, 1]
# 17                   0.666667  [3, 1, 2, 0]       [1, 0, 3, 2]
# 18                   1.000000     [0, 1, 2]          [1, 2, 0]
# 19                   0.666667  [3, 2, 0, 1]       [1, 0, 3, 2]
# 20                   1.000000  [3, 2, 1, 0]       [0, 1, 2, 3]

# %%
evaluate_model(list(Path("../experiments/data/test/").glob("*.yaml")), CAM)
# Out:
# 100%|██████████| 21/21 [00:27<00:00,  1.30s/it]
#                                               name baseline  backward_count  \
# 0          linear_non_gaussian_3_1000_full_uniform      CAM               0
# 1   linear_non_gaussian_3_1000_v_structure_laplace      CAM               1
# 2          linear_non_gaussian_4_1000_full_uniform      CAM               1
# 3   linear_non_gaussian_3_1000_erdos_renyi_uniform      CAM               2
# 4         linear_non_gaussian_2_1000_chain_laplace      CAM               0
# 5   linear_non_gaussian_4_1000_v_structure_laplace      CAM               1
# 6         linear_non_gaussian_3_1000_chain_uniform      CAM               1
# 7   linear_non_gaussian_4_1000_erdos_renyi_uniform      CAM               1
# 8          linear_non_gaussian_4_1000_fork_uniform      CAM               0
# 9          linear_non_gaussian_3_1000_fork_uniform      CAM               1
# 10        linear_non_gaussian_4_1000_chain_uniform      CAM               0
# 11  linear_non_gaussian_3_1000_erdos_renyi_laplace      CAM               0
# 12         linear_non_gaussian_4_1000_full_laplace      CAM               2
# 13        linear_non_gaussian_2_1000_chain_uniform      CAM               0
# 14         linear_non_gaussian_3_1000_full_laplace      CAM               0
# 15  linear_non_gaussian_4_1000_erdos_renyi_laplace      CAM               0
# 16        linear_non_gaussian_3_1000_chain_laplace      CAM               0
# 17  linear_non_gaussian_4_1000_v_structure_uniform      CAM               1
# 18         linear_non_gaussian_3_1000_fork_laplace      CAM               0
# 19         linear_non_gaussian_4_1000_fork_laplace      CAM               1
# 20        linear_non_gaussian_4_1000_chain_laplace      CAM               0
#
#     backward_relative_penalty true_ordering estimated_ordering
# 0                    0.000000     [1, 2, 0]          [1, 2, 0]
# 1                    0.500000     [0, 2, 1]          [2, 1, 0]
# 2                    0.166667  [3, 2, 1, 0]       [3, 2, 0, 1]
# 3                    0.666667     [1, 0, 2]          [2, 1, 0]
# 4                    0.000000        [1, 0]             [1, 0]
# 5                    0.333333  [0, 3, 1, 2]       [3, 0, 2, 1]
# 6                    0.500000     [1, 2, 0]          [2, 1, 0]
# 7                    0.333333  [3, 0, 1, 2]       [0, 2, 3, 1]
# 8                    0.000000  [3, 2, 1, 0]       [3, 0, 1, 2]
# 9                    0.500000     [2, 0, 1]          [0, 2, 1]
# 10                   0.000000  [1, 0, 3, 2]       [1, 0, 3, 2]
# 11                   0.000000     [0, 1, 2]          [0, 1, 2]
# 12                   0.333333  [1, 3, 0, 2]       [3, 1, 2, 0]
# 13                   0.000000        [1, 0]             [1, 0]
# 14                   0.000000     [1, 2, 0]          [1, 2, 0]
# 15                   0.000000  [3, 0, 2, 1]       [0, 2, 3, 1]
# 16                   0.000000     [1, 0, 2]          [1, 0, 2]
# 17                   0.333333  [3, 1, 2, 0]       [2, 3, 0, 1]
# 18                   0.000000     [0, 1, 2]          [0, 2, 1]
# 19                   0.333333  [3, 2, 0, 1]       [2, 3, 0, 1]
# 20                   0.000000  [3, 2, 1, 0]       [3, 2, 1, 0]

# %%
evaluate_model(list(Path("../experiments/data/test/").glob("*.yaml")), Score)
# Out:
# 100%|██████████| 21/21 [00:21<00:00,  1.00s/it]
#                                               name baseline  backward_count  \
# 0          linear_non_gaussian_3_1000_full_uniform    Score               1
# 1   linear_non_gaussian_3_1000_v_structure_laplace    Score               0
# 2          linear_non_gaussian_4_1000_full_uniform    Score               5
# 3   linear_non_gaussian_3_1000_erdos_renyi_uniform    Score               3
# 4         linear_non_gaussian_2_1000_chain_laplace    Score               0
# 5   linear_non_gaussian_4_1000_v_structure_laplace    Score               1
# 6         linear_non_gaussian_3_1000_chain_uniform    Score               2
# 7   linear_non_gaussian_4_1000_erdos_renyi_uniform    Score               3
# 8          linear_non_gaussian_4_1000_fork_uniform    Score               3
# 9          linear_non_gaussian_3_1000_fork_uniform    Score               1
# 10        linear_non_gaussian_4_1000_chain_uniform    Score               0
# 11  linear_non_gaussian_3_1000_erdos_renyi_laplace    Score               2
# 12         linear_non_gaussian_4_1000_full_laplace    Score               3
# 13        linear_non_gaussian_2_1000_chain_uniform    Score               1
# 14         linear_non_gaussian_3_1000_full_laplace    Score               1
# 15  linear_non_gaussian_4_1000_erdos_renyi_laplace    Score               1
# 16        linear_non_gaussian_3_1000_chain_laplace    Score               1
# 17  linear_non_gaussian_4_1000_v_structure_uniform    Score               1
# 18         linear_non_gaussian_3_1000_fork_laplace    Score               1
# 19         linear_non_gaussian_4_1000_fork_laplace    Score               3
# 20        linear_non_gaussian_4_1000_chain_laplace    Score               1
#
#     backward_relative_penalty true_ordering estimated_ordering
# 0                    0.333333     [1, 2, 0]          [1, 0, 2]
# 1                    0.000000     [0, 2, 1]          [0, 2, 1]
# 2                    0.833333  [3, 2, 1, 0]       [1, 0, 2, 3]
# 3                    1.000000     [1, 0, 2]          [2, 0, 1]
# 4                    0.000000        [1, 0]             [1, 0]
# 5                    0.333333  [0, 3, 1, 2]       [1, 0, 2, 3]
# 6                    1.000000     [1, 2, 0]          [0, 2, 1]
# 7                    1.000000  [3, 0, 1, 2]       [1, 2, 0, 3]
# 8                    1.000000  [3, 2, 1, 0]       [2, 1, 0, 3]
# 9                    0.500000     [2, 0, 1]          [0, 2, 1]
# 10                   0.000000  [1, 0, 3, 2]       [1, 0, 3, 2]
# 11                   1.000000     [0, 1, 2]          [2, 1, 0]
# 12                   0.500000  [1, 3, 0, 2]       [3, 0, 2, 1]
# 13                   1.000000        [1, 0]             [0, 1]
# 14                   0.333333     [1, 2, 0]          [1, 0, 2]
# 15                   1.000000  [3, 0, 2, 1]       [1, 2, 0, 3]
# 16                   0.500000     [1, 0, 2]          [0, 2, 1]
# 17                   0.333333  [3, 1, 2, 0]       [1, 3, 0, 2]
# 18                   0.500000     [0, 1, 2]          [2, 0, 1]
# 19                   1.000000  [3, 2, 0, 1]       [1, 2, 0, 3]
# 20                   0.333333  [3, 2, 1, 0]       [0, 3, 2, 1]
